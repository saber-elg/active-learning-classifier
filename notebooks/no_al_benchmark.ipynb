# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import cifar10

# %%
# Charger le jeu de données CIFAR-10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Prétraitement des données
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convertir les étiquettes en encodage one-hot
num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
# Définir les paramètres du modèle
input_shape = x_train.shape[1:]

# %%
# Construire le modèle directement
inputs = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)

x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.25)(x)

x = Flatten()(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.5)(x)

outputs = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# Compiler le modèle
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Entraîner le modèle
history = model.fit(
    x_train, y_train,
    batch_size=64,
    epochs=20,
    validation_split=0.2,
    shuffle=True
)

# Évaluer le modèle
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 43ms/step - accuracy: 0.2097 - loss: 2.0797 - val_accuracy: 0.4625 - val_loss: 1.5125
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.4114 - loss: 1.6018 - val_accuracy: 0.5127 - val_loss: 1.3368
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - accuracy: 0.4769 - loss: 1.4502 - val_accuracy: 0.5578 - val_loss: 1.2480
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5125 - loss: 1.3504 - val_accuracy: 0.5938 - val_loss: 1.1555
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.5375 - loss: 1.2903 - val_accuracy: 0.6273 - val_loss: 1.0567
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 45ms/step - accuracy: 0.5631 - loss: 1.2223 - val_accuracy: 0.6407 - val_loss: 1.0415
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.5937 - loss: 1.1670 - val_accuracy: 0.6618 - val_loss: 0.9645
# Epoch 8/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 45ms/step - accuracy: 0.6059 - loss: 1.1168 - val_accuracy: 0.6592 - val_loss: 0.9743
# Epoch 9/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.6122 - loss: 1.0997 - val_accuracy: 0.6764 - val_loss: 0.9166
# Epoch 10/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.6211 - loss: 1.0800 - val_accuracy: 0.6990 - val_loss: 0.8767
# Epoch 11/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.6375 - loss: 1.0339 - val_accuracy: 0.6924 - val_loss: 0.8776
# Epoch 12/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.6488 - loss: 1.0066 - val_accuracy: 0.6946 - val_loss: 0.8749
# Epoch 13/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 29s 46ms/step - accuracy: 0.6478 - loss: 1.0025 - val_accuracy: 0.7145 - val_loss: 0.8217
# Epoch 14/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 30s 47ms/step - accuracy: 0.6534 - loss: 0.9970 - val_accuracy: 0.7145 - val_loss: 0.8205
# Epoch 15/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.6610 - loss: 0.9725 - val_accuracy: 0.7162 - val_loss: 0.8258
# Epoch 16/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - accuracy: 0.6658 - loss: 0.9567 - val_accuracy: 0.7285 - val_loss: 0.7889
# Epoch 17/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.6697 - loss: 0.9513 - val_accuracy: 0.7236 - val_loss: 0.7963
# Epoch 18/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 39ms/step - accuracy: 0.6753 - loss: 0.9300 - val_accuracy: 0.7281 - val_loss: 0.7950
# Epoch 19/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6798 - loss: 0.9283 - val_accuracy: 0.7368 - val_loss: 0.7715
# Epoch 20/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.6796 - loss: 0.9245 - val_accuracy: 0.7307 - val_loss: 0.7806
# 313/313 - 2s - 6ms/step - accuracy: 0.7295 - loss: 0.7872
# Test Loss: 0.7872084975242615
# Test Accuracy: 0.7294999957084656
